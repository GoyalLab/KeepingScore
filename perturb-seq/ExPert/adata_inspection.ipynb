# %%
import anndata as ad
import scanpy as sc

# %%
adata = sc.read_h5ad("latent_space.h5ad")
adata.obs
# Out:
#                                                    perturbation  efficiency  \
# AAACCAATCATTAGTCAACGGGAA-1_CD4i_R1L08_CD4i_R1_D...         EIF1    1.530678
# AAAGTCATCGCGTTACACTTTAGG-1_CD4i_R1L08_CD4i_R1_D...        PSMB5    2.852200
# AACCAACAGAGCAACTAACGGGAA-1_CD4i_R1L08_CD4i_R1_D...      ANKRD11   -0.138770
# AACCCGGCAATGTTCCACTTTAGG-1_CD4i_R1L08_CD4i_R1_D...         PTMA    3.128171
# AAGACAACACTATCACATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...         PTMA    2.286528
# ...                                                         ...         ...
# GCCTGGGGTGTGTTCC-HEK293T_Batch223;XAtlas2025_HE...     C17orf58   -0.003224
# GCTTCGACAAACGCAA-HEK293T_Batch223;XAtlas2025_HE...       PAXBP1   -0.325724
# GTAAGGTAGCTAACAT-HEK293T_Batch223;XAtlas2025_HE...        DDX46    0.303106
# GTCGCCAAGACCATGC-HEK293T_Batch223;XAtlas2025_HE...       MRPL24    2.836627
# GTCTGCGAGCTCAGCG-HEK293T_Batch223;XAtlas2025_HE...       OGFOD1    0.250446
#
# ...

# %%
(adata.obs["perturbation"] == "EIF1").any()
# Out:
# True
